# %% [markdown]
# # Aspect Extraction

# %%
from pprint import pprint # pretty print

# %%
# We get started by importing spacy
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x1ceb0e0d6d0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x1ceb0e0f470>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x1ceb0d80e40>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x1ceb0f81b90>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x1ceaf792290>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x1ceaf8cee30>)]

# %%
sentences = [
  'The food we had yesterday was delicious',
  'My time in Italy was very enjoyable',
  'I found the meal to be tasty',
  'The internet was slow.',
  'Our experience was suboptimal',
  'anc work in the first 3 days but the proximity sensor on the left bud stopped working',
  'shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰',
  "Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾",
  'Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !',
  "been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog",
  'wrong color. poor packaging',
  'Delivery and shipment were both okay.',
  """If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
Worth the money. Have fun!""",
  "I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY"
]

# %%
from spacy import displacy
testtext = nlp(sentences[-1])
displacy.render(testtext, style = "dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0d5a800397ff4b0b88d0f94d8ea3d5fe-0" class="displacy" width="16150" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">hesitant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">heard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">lots</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">things</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">brand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">got</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">since</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">’ve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">kinda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">crushing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">friend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">mine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">CCONJ</tspan>
# </text>
#
# <text c

# %%
displacy.render(testtext, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I was hesitant at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . I put it on and he complimented the way I smelled twice and by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of the night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY</div></span>

# %%
displacy.render(testtext, style='dep', options={'compact': True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f01a923e6e45462c84fa428f057c4feb-0" class="displacy" width="13850" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">hesitant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">heard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">lots</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">good</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">things</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">brand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">got</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">since</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">’ve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">kinda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">crushing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">friend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">mine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4550">CCONJ</tspan>
# </text>
#
# <text cla

# %% [markdown]
# For each token inside our sentences, we can see the dependency thanks to spacy’s dependency parsing and the POS (Part-Of-Speech) tags. We’re also paying attention to the child tokens, so that we’re able to pick up intensifiers such as “very”, “quite”, and more.

# %%
for sentence in sentences:
  doc = nlp(sentence)
  for token in doc:
    print(token.text, spacy.explain(token.dep_), token.head.text, spacy.explain(token.head.pos_),
      token.pos_,[child for child in token.children], sep=' | ')
# Out:
# The | determiner | food | noun | DET | []
# food | nominal subject | was | auxiliary | NOUN | [The, had]
# we | nominal subject | had | verb | PRON | []
# had | relative clause modifier | food | noun | VERB | [we, yesterday]
# yesterday | noun phrase as adverbial modifier | had | verb | NOUN | []
# was | root | was | auxiliary | AUX | [food, delicious]
# delicious | adjectival complement | was | auxiliary | ADJ | []
# My | possession modifier | time | noun | PRON | []
# time | nominal subject | was | auxiliary | NOUN | [My, in]
# in | prepositional modifier | time | noun | ADP | [Italy]
# Italy | object of preposition | in | adposition | PROPN | []
# was | root | was | auxiliary | AUX | [time, enjoyable]
# very | adverbial modifier | enjoyable | adjective | ADV | []
# enjoyable | adjectival complement | was | auxiliary | ADJ | [very]
# I | nominal subject | found | verb | PRON | []
# found | root | found | verb | VERB | [I, be]
# the | determiner | meal | noun | DET | []
# meal | nominal subject | be | auxiliary | NOUN | [the]
# to | auxiliary | be | auxiliary | PART | []
# be | clausal complement | found | verb | AUX | [meal, to, tasty]
# tasty | adjectival complement | be | auxiliary | ADJ | []
# The | determiner | internet | noun | DET | []
# internet | nominal subject | was | auxiliary | NOUN | [The]
# was | root | was | auxiliary | AUX | [internet, slow, .]
# slow | adjectival complement | was | auxiliary | ADJ | []
# . | punctuation | was | auxiliary | PUNCT | []
# Our | possession modifier | experience | noun | PRON | []
# experience | nominal subject | was | auxiliary | NOUN | [Our]
# was | root | was | auxiliary | AUX | [experience, suboptimal]
# suboptimal | adjectival complement | was | auxiliary | ADJ | []
# anc | nominal subject | work | verb | PROPN | []
# work | root | work | verb | VERB | [anc, in, but, stopped]
# in | prepositional modifier | work | verb | ADP | [days]
# the | determiner | days | noun | DET | []
# first | adjectival modifier | days | noun | ADJ | []
# 3 | numeric modifier | days | noun | NUM | []
# days | object of preposition | in | adposition | NOUN | [the, first, 3]
# but | coordinating conjunction | work | verb | CCONJ | []
# the | determiner | sensor | noun | DET | []
# proximity | compound | sensor | noun | NOUN | []
# sensor | nominal subject | stopped | verb | NOUN | [the, proximity, on]
# on | prepositional modifier | sensor | noun | ADP | [bud]
# the | determiner | bud | noun | DET | []
# left | adjectival modifier | bud | noun | ADJ | []
# bud | object of preposition | on | adposition | NOUN | [the, left]
# stopped | conjunct | work | verb | VERB | [sensor, working]
# working | open clausal complement | stopped | verb | VERB | []
# shipped | clausal subject | order | verb | VERB | [out, immediately, ,, received, thank]
# out | particle | shipped | verb | ADP | []
# immediately | adverbial modifier | shipped | verb | ADV | []
# , | punctuation | shipped | verb | PUNCT | []
# received | conjunct | shipped | verb | VERB | [item, in, ,]
# the | determiner | item | noun | DET | []
# item | direct object | received | verb | NOUN | [the]
# in | prepositional modifier | received | verb | ADP | [condition]
# good | adjectival modifier | condition | noun | ADJ | []
# condition | object of preposition | in | adposition | NOUN | [good]
# , | punctuation | received | verb | PUNCT | []
# no | determiner | damage | noun | DET | []
# damage | nominal subject | thank | verb | NOUN | [no, packed, ,]
# well | adverbial modifier | packed | verb | ADV | []
# packed | adjectival modifier | damage | noun | VERB | [well]
# , | punctuation | damage | noun | PUNCT | []
# thank | conjunct | shipped | verb | VERB | [damage, you, shopee, and, thank, ,]
# you | direct object | thank | verb | PRON | []
# shopee | object predicate | thank | verb | VERB | []
# and | coordinating conjunction | thank | verb | CCONJ | []
# thank | conjunct | thank | verb | VERB | [you, seller]
# you | direct object | thank | verb | PRON | []
# seller | object predicate | thank | verb | NOUN | []
# , | punctuation | thank | verb | PUNCT | []
# will | auxiliary | order | verb | AUX | []
# order | root | order | verb | VERB | [shipped, will, again, 👍, 😁, 👌, 🫰]
# again | adverbial modifier | order | verb | ADV | []
# 👍 | punctuation | order | verb | PUNCT | []
# 😁 | punctuation | order | verb | X | []
# 👌 | direct object | order | verb | NUM | []
# 🫰 | direct object | order | verb | X | []
# Tysm | root | Tysm | proper noun | PROPN | [for, .]
# for | prepositional modifier | Tysm | proper noun | ADP | [delivering]
# delivering | complement of preposition | for | adposition | VERB | [items, safely]
# my | possession modifier | items | noun | PRON | []
# items | direct object | delivering | verb | NOUN | [my]
# safely | adverbial modifier | delivering | verb | ADV | []
# . | punctuation | Tysm | proper noun | PUNCT | []
# I | nominal subject | expected | verb | PRON | []
# only | adverbial modifier | expected | verb | ADV | []
# expected | root | expected | verb | VERB | [I, only, gave, ,, but, did]
# the | determiner | seller | noun | DET | []
# seller | nominal subject | gave | verb | NOUN | [the]
# gave | clausal complement | expected | verb | VERB | [seller, freebies]
# some | determiner | freebies | noun | DET | []
# freebies | direct object | gave | verb | NOUN | [some]
# , | punctuation | expected | verb | PUNCT | []
# but | coordinating conjunction | expected | verb | CCONJ | []
# he | nominal subject | did | verb | PRON | []
# / | punctuation | did | verb | PUNCT | []
# she | nominal subject | did | verb | PRON | []
# did | conjunct | expected | verb | VERB | [he, /, she, n't, 😂, 😂, 😾]
# n't | negation modifier | did | verb | PART | []
# 😂 | unclassified dependent | did | verb | ADV | []
# 😂 | direct object | did | verb | NUM | []
# 😾 | direct object | did | verb | X | []
# Sobrang | compound | dumating | proper noun | PROPN | []
# tagal | compound | dumating | proper noun | PROPN | []
# lang | compound | dumating | proper noun | PROPN | []
# dumating | root | dumating | proper noun | PROPN | [Sobrang, tagal, lang, .]
# . | punctuation | dumating | proper noun | PUNCT | []
# Pero | compound | lang | proper noun | PROPN | []
# okay | compound | lang | proper noun | PROPN | []
# lang | root | lang | proper noun | PROPN | [Pero, okay, ,, naman, .]
# , | punctuation | lang | proper noun | PUNCT | []
# sulit | compound | naman | proper noun | PROPN | []
# naman | appositional modifier | lang | proper noun | PROPN | [sulit]
# . | punctuation | lang | proper noun | PUNCT | []
# Nakuha | compound | halagang | proper noun | PROPN | []
# ko | compound | halagang | proper noun | PROPN | []
# sya | compound | halagang | proper noun | PROPN | []
# sa | compound | halagang | proper noun | PROPN | []
# halagang | root | halagang | proper noun | PROPN | [Nakuha, ko, sya, sa, pesos, .]
# 999 | numeric modifier | pesos | noun | NUM | []
# pesos | appositional modifier | halagang | proper noun | NOUN | [999]
# . | punctuation | halagang | proper noun | PUNCT | []
# Nagsale | compound | kasi | proper noun | PROPN | []
# kasi | root | kasi | proper noun | PROPN | [Nagsale, .]
# . | punctuation | kasi | proper noun | PUNCT | []
# 😍 | adverbial modifier | Thank | verb | ADV | []
# Thank | root | Thank | verb | VERB | [😍, youuu, !]
# youuu | direct object | Thank | verb | NOUN | []
# ! | punctuation | Thank | verb | PUNCT | []
# Legit | root | Legit | adjective | ADJ | [!]
# ! | punctuation | Legit | adjective | PUNCT | []
# been | auxiliary | using | verb | AUX | []
# using | root | using | verb | VERB | [been, buds, for, na]
# this | determiner | buds | noun | DET | []
# buds | direct object | using | verb | NOUN | [this]
# for | prepositional modifier | using | verb | ADP | [weeks]
# 2 | numeric modifier | weeks | noun | NUM | []
# weeks | object of preposition | for | adposition | NOUN | [2]
# na | punctuation | using | verb | ADV | []
# and | coordinating conjunction | notice | verb | CCONJ | []
# I | nominal subject | notice | verb | PRON | []
# notice | root | notice | verb | VERB | [and, I, took, .]
# that | marker | took | verb | SCONJ | []
# sometimes | adverbial modifier | took | verb | ADV | []
# it | nominal subject | took | verb | PRON | []
# took | clausal complement | notice | verb | VERB | [that, sometimes, it, long, connect, know]
# so | adverbial modifier | long | adjective | ADV | []
# long | adverbial modifier | took | verb | ADJ | [so]
# to | auxiliary | connect | verb | PART | []
# connect | open clausal complement | took | verb | VERB | [to, on]
# on | prepositional modifier | connect | verb | ADP | [laptop]
# my | possession modifier | laptop | noun | PRON | []
# laptop | object of preposition | on | adposition | NOUN | [my, and, phone]
# and | coordinating conjunction | laptop | noun | CCONJ | []
# phone | conjunct | laptop | noun | NOUN | []
# I | nominal subject | know | verb | PRON | []
# do | auxiliary | know | verb | AUX | []
# n't | negation modifier | know | verb | PART | []
# know | conjunct | took | verb | VERB | [I, do, n't, why]
# why | adverbial modifier | know | verb | SCONJ | []
# . | punctuation | notice | verb | PUNCT | []
# then | adverbial modifier | yung | proper noun | ADV | []
# sometimes | adverbial modifier | sound | proper noun | ADV | []
# nagkaproblem | compound | sound | proper noun | PROPN | []
# sound | compound | yung | proper noun | PROPN | [sometimes, nagkaproblem]
# nya | compound | yung | proper noun | PROPN | []
# parang | compound | yung | proper noun | PROPN | []
# basag | compound | yung | proper noun | PROPN | []
# yung | root | yung | proper noun | PROPN | [then, sound, nya, parang, basag, tunog]
# tunog | noun phrase as adverbial modifier | yung | proper noun | PROPN | []
# wrong | adjectival modifier | color | noun | ADJ | []
# color | root | color | noun | NOUN | [wrong, .]
# . | punctuation | color | noun | PUNCT | []
# poor | adjectival modifier | packaging | noun | ADJ | []
# packaging | root | packaging | noun | NOUN | [poor]
# Delivery | nominal subject | were | auxiliary | NOUN | [and, shipment]
# and | coordinating conjunction | Delivery | noun | CCONJ | []
# shipment | conjunct | Delivery | noun | NOUN | []
# were | root | were | auxiliary | AUX | [Delivery, both, okay, .]
# both | unclassified dependent | were | auxiliary | PRON | []
# okay | adjectival complement | were | auxiliary | ADJ | []
# . | punctuation | were | auxiliary | PUNCT | []
# If | marker | intend | verb | SCONJ | []
# you | nominal subject | intend | verb | PRON | []
# intend | adverbial clause modifier | prepared | verb | VERB | [If, you, use]
# to | auxiliary | use | verb | PART | []
# use | open clausal complement | intend | verb | VERB | [to, this, attract, ,]
# this | direct object | use | verb | PRON | []
# to | auxiliary | attract | verb | PART | []
# attract | open clausal complement | use | verb | VERB | [to, man]
# your | possession modifier | man | noun | PRON | []
# man | direct object | attract | verb | NOUN | [your]
# , | punctuation | use | verb | PUNCT | []
# be | auxiliary (passive) | prepared | verb | AUX | []
# prepared | root | prepared | verb | VERB | [intend, be, for, .]
# for | prepositional modifier | prepared | verb | ADP | [result]
# a | determiner | result | noun | DET | []
# ravenous | adjectival modifier | result | noun | ADJ | []
# , | punctuation | result | noun | PUNCT | []
# passionate | adjectival modifier | result | noun | ADJ | []
# result | object of preposition | for | adposition | NOUN | [a, ravenous, ,, passionate]
# . | punctuation | prepared | verb | PUNCT | []
# Do | auxiliary | use | verb | AUX | []
# not | negation modifier | use | verb | PART | []
# use | root | use | verb | VERB | [Do, not, intend, .]
# if | marker | intend | verb | SCONJ | []
# you | nominal subject | intend | verb | PRON | []
# do | auxiliary | intend | verb | AUX | []
# n’t | negation modifier | intend | verb | PART | []
# intend | adverbial clause modifier | use | verb | VERB | [if, you, do, n’t, follow]
# to | auxiliary | follow | verb | PART | []
# follow | open clausal complement | intend | verb | VERB | [to, through, with]
# through | particle | follow | verb | ADP | []
# with | prepositional modifier | follow | verb | ADP | [target]
# your | possession modifier | target | noun | PRON | []
# intended | adjectival modifier | target | noun | VERB | []
# target | object of preposition | with | adposition | NOUN | [your, intended]
# . | punctuation | use | verb | PUNCT | []
# That | nominal subject | ’s | verb | PRON | []
# ’s | root | ’s | verb | VERB | [That, move, .]
# a | determiner | move | noun | DET | []
# d | modifier of nominal | move | noun | NOUN | []
# * | modifier of nominal | move | noun | PUNCT | []
# * | punctuation | move | noun | PUNCT | []
# * | adjectival modifier | move | noun | ADJ | []
# move | attribute | ’s | verb | NOUN | [a, d, *, *, *]
# . | punctuation | ’s | verb | PUNCT | []
# Plus | coordinating conjunction | is | auxiliary | CCONJ | []
# this | determiner | stuff | noun | DET | []
# stuff | nominal subject | is | auxiliary | NOUN | [this]
# is | root | is | auxiliary | AUX | [Plus, stuff, potent, and, have]
# potent | adjectival complement | is | auxiliary | ADJ | []
# and | coordinating conjunction | is | auxiliary | CCONJ | []
# you | nominal subject | have | verb | PRON | []
# have | conjunct | is | auxiliary | VERB | [you, idea, .]
# no | determiner | idea | noun | DET | []
# idea | direct object | have | verb | NOUN | [no, respond]
# how | adverbial modifier | respond | verb | SCONJ | []
# a | determiner | man | noun | DET | []
# man | nominal subject | respond | verb | NOUN | [a]
# might | auxiliary | respond | verb | AUX | []
# respond | relative clause modifier | idea | noun | VERB | [how, man, might, to]
# to | prepositional modifier | respond | verb | ADP | [call]
# its | possession modifier | call | noun | PRON | []
# siren | adjectival modifier | call | noun | ADJ | []
# call | object of preposition | to | adposition | NOUN | [its, siren]
# . | punctuation | have | verb | PUNCT | []
# It | nominal subject | ’s | verb | PRON | []
# ’s | root | ’s | verb | VERB | [It, basically, potion, handle, .]
# basically | adverbial modifier | ’s | verb | ADV | []
# a | determiner | potion | noun | DET | []
# love | compound | potion | noun | NOUN | []
# potion | attribute | ’s | verb | NOUN | [a, love]
# so | adverbial modifier | handle | verb | ADV | []
# handle | adverbial clause modifier | ’s | verb | VERB | [so, with]
# with | prepositional modifier | handle | verb | ADP | [care]
# care | object of preposition | with | adposition | NOUN | []
# . | punctuation | ’s | verb | PUNCT | []
# But | coordinating conjunction | works | verb | CCONJ | []
# it | nominal subject | works | verb | PRON | []
# absolutely | adverbial modifier | works | verb | ADV | []
# works | root | works | verb | VERB | [But, it, absolutely, !]
# ! | punctuation | works | verb | PUNCT | [
# ]
#
#  | unclassified dependent | ! | punctuation | SPACE | []
# Tip | noun phrase as adverbial modifier | let | verb | NOUN | [1]
# 1 | numeric modifier | Tip | noun | NUM | []
# : | punctuation | let | verb | PUNCT | []
# let | adverbial clause modifier | ’s | verb | VERB | [Tip, :, settle]
# it | nominal subject | settle | verb | PRON | []
# settle | clausal complement | let | verb | VERB | [it, after]
# after | prepositional modifier | settle | verb | ADP | [application]
# application | object of preposition | after | adposition | NOUN | []
# , | punctuation | ’s | verb | PUNCT | []
# it | nominal subject | ’s | verb | PRON | []
# ’s | root | ’s | verb | VERB | [let, ,, it, smelling, ,, but, mellows, .]
# strong | adjectival modifier | smelling | noun | ADJ | [but, nice]
# but | coordinating conjunction | strong | adjective | CCONJ | []
# nice | conjunct | strong | adjective | ADJ | []
# smelling | direct object | ’s | verb | NOUN | [strong, at]
# at | prepositional modifier | smelling | noun | ADP | [first]
# first | complement of preposition | at | adposition | ADV | []
# , | punctuation | ’s | verb | PUNCT | []
# but | coordinating conjunction | ’s | verb | CCONJ | []
# mellows | conjunct | ’s | verb | VERB | [out, over]
# out | particle | mellows | verb | ADP | []
# over | prepositional modifier | mellows | verb | ADP | [time]
# time | object of preposition | over | adposition | NOUN | []
# . | punctuation | ’s | verb | PUNCT | [
# ]
#
#  | unclassified dependent | . | punctuation | SPACE | []
# Tip | nominal subject | combine | verb | PROPN | [2, :]
# 2 | numeric modifier | Tip | proper noun | NUM | []
# : | punctuation | Tip | proper noun | PUNCT | []
# combine | root | combine | verb | VERB | [Tip, with, .]
# with | prepositional modifier | combine | verb | ADP | [perfume]
# your | possession modifier | perfume | noun | PRON | []
# perfume | object of preposition | with | adposition | NOUN | [your, of, ,, one]
# of | prepositional modifier | perfume | noun | ADP | [choice]
# choice | object of preposition | of | adposition | NOUN | []
# , | punctuation | perfume | noun | PUNCT | []
# particularly | adverbial modifier | one | noun | ADV | []
# one | appositional modifier | perfume | noun | NOUN | [particularly, has]
# that | nominal subject | has | verb | PRON | []
# has | relative clause modifier | one | noun | VERB | [that, trigger]
# a | determiner | trigger | noun | DET | []
# positive | adjectival modifier | trigger | noun | ADJ | []
# olfactory | compound | memory | noun | NOUN | []
# memory | compound | trigger | noun | NOUN | [olfactory]
# trigger | direct object | has | verb | NOUN | [a, positive, memory, with]
# with | prepositional modifier | trigger | noun | ADP | [target]
# your | possession modifier | target | noun | PRON | []
# partner | noun phrase as adverbial modifier | intended | verb | NOUN | []
# / | punctuation | intended | verb | SYM | []
# intended | adjectival modifier | target | noun | VERB | [partner, /]
# target | object of preposition | with | adposition | NOUN | [your, intended]
# . | punctuation | combine | verb | PUNCT | [
# ]
#
#  | unclassified dependent | . | punctuation | SPACE | []
# Tip | nominal subject | use | verb | PROPN | [3, :]
# 3 | numeric modifier | Tip | proper noun | NUM | []
# : | punctuation | Tip | proper noun | PUNCT | []
# do | auxiliary | use | verb | AUX | []
# n’t | negation modifier | use | verb | PART | []
# use | root | use | verb | VERB | [Tip, do, n’t, much, ,, or, becomes]
# too | adverbial modifier | much | adjective | ADV | []
# much | direct object | use | verb | ADJ | [too]
# , | punctuation | use | verb | PUNCT | []
# or | coordinating conjunction | use | verb | CCONJ | []
# it | nominal subject | becomes | verb | PRON | []
# becomes | conjunct | use | verb | VERB | [it, turn, tested, ), !]
# a | determiner | turn | noun | DET | []
# turn | attribute | becomes | verb | NOUN | [a, OFF]
# OFF | adverbial modifier | turn | noun | PROPN | []
# ( | punctuation | tested | verb | PUNCT | []
# tested | unclassified dependent | becomes | verb | VERB | [(, and, confirmed]
# and | coordinating conjunction | tested | verb | CCONJ | []
# confirmed | conjunct | tested | verb | VERB | []
# ) | punctuation | becomes | verb | PUNCT | []
# ! | punctuation | becomes | verb | PUNCT | []
# A | determiner | dab | noun | DET | []
# dab | nominal subject | do | verb | NOUN | [A, or, swipe]
# or | coordinating conjunction | dab | noun | CCONJ | []
# small | adjectival modifier | swipe | noun | ADJ | []
# swipe | conjunct | dab | noun | NOUN | [small, on]
# on | prepositional modifier | swipe | noun | ADP | [wrists]
# wrists | object of preposition | on | adposition | NOUN | [and, jaw]
# and | coordinating conjunction | wrists | noun | CCONJ | []
# chest | modifier of nominal | jaw | noun | NOUN | [or, behind]
# or | coordinating conjunction | chest | noun | CCONJ | []
# behind | conjunct | chest | noun | ADP | [ear]
# ear | object of preposition | behind | adposition | NOUN | []
# / | punctuation | jaw | noun | SYM | []
# jaw | conjunct | wrists | noun | NOUN | [chest, /]
# should | auxiliary | do | verb | AUX | []
# do | root | do | verb | VERB | [dab, should, it, Worth, .]
# it | direct object | do | verb | PRON | [
# ]
#
#  | unclassified dependent | it | pronoun | SPACE | []
# Worth | adverbial clause modifier | do | verb | PROPN | [money]
# the | determiner | money | noun | DET | []
# money | direct object | Worth | proper noun | NOUN | [the]
# . | punctuation | do | verb | PUNCT | []
# Have | root | Have | verb | VERB | [fun, !]
# fun | direct object | Have | verb | NOUN | []
# ! | punctuation | Have | verb | PUNCT | []
# I | nominal subject | was | auxiliary | PRON | []
# was | root | was | auxiliary | AUX | [I, hesitant, at, but, heard]
# hesitant | adjectival complement | was | auxiliary | ADJ | []
# at | prepositional modifier | was | auxiliary | ADP | [first]
# first | complement of preposition | at | adposition | ADV | []
# but | coordinating conjunction | was | auxiliary | CCONJ | []
# I | nominal subject | heard | verb | PRON | []
# heard | conjunct | was | auxiliary | VERB | [I, lots]
# lots | direct object | heard | verb | NOUN | [of]
# of | prepositional modifier | lots | noun | ADP | [things]
# good | adjectival modifier | things | noun | ADJ | []
# things | object of preposition | of | adposition | NOUN | [good, about]
# about | prepositional modifier | things | noun | ADP | [brand]
# this | determiner | brand | noun | DET | []
# brand | object of preposition | about | adposition | NOUN | [this]
# so | adverbial modifier | got | verb | SCONJ | []
# I | nominal subject | got | verb | PRON | []
# got | root | got | verb | VERB | [so, I, it, crushing, and, coming]
# it | direct object | got | verb | PRON | []
# since | marker | been | auxiliary | SCONJ | []
# I | nominal subject | been | auxiliary | PRON | []
# ’ve | auxiliary | been | auxiliary | AUX | []
# been | auxiliary | crushing | verb | AUX | [since, I, ’ve]
# kinda | adverbial modifier | crushing | verb | ADV | []
# crushing | clausal complement | got | verb | VERB | [been, kinda, on]
# on | prepositional modifier | crushing | verb | ADP | [friend]
# a | determiner | friend | noun | DET | []
# friend | object of preposition | on | adposition | NOUN | [a, of]
# of | prepositional modifier | friend | noun | ADP | [mine]
# mine | object of preposition | of | adposition | NOUN | []
# and | coordinating conjunction | got | verb | CCONJ | []
# he | nominal subject | coming | verb | PRON | []
# was | auxiliary | coming | verb | AUX | []
# coming | conjunct | got | verb | VERB | [he, was, over, for, .]
# over | particle | coming | verb | ADP | []
# for | prepositional modifier | coming | verb | ADP | [weekend]
# the | determiner | weekend | noun | DET | []
# weekend | object of preposition | for | adposition | NOUN | [the]
# . | punctuation | coming | verb | PUNCT | []
# I | nominal subject | put | verb | PRON | []
# put | root | put | verb | VERB | [I, it, on, and, complimented]
# it | direct object | put | verb | PRON | []
# on | particle | put | verb | ADP | []
# and | coordinating conjunction | put | verb | CCONJ | []
# he | nominal subject | complimented | verb | PRON | []
# complimented | conjunct | put | verb | VERB | [he, way, and, by, .]
# the | determiner | way | noun | DET | []
# way | direct object | complimented | verb | NOUN | [the, smelled]
# I | nominal subject | smelled | verb | PRON | []
# smelled | relative clause modifier | way | noun | VERB | [I, twice]
# twice | adverbial modifier | smelled | verb | ADV | []
# and | coordinating conjunction | complimented | verb | CCONJ | []
# by | conjunct | complimented | verb | ADP | [end]
# the | determiner | end | noun | DET | []
# end | object of preposition | by | adposition | NOUN | [the, of]
# of | prepositional modifier | end | noun | ADP | [night]
# the | determiner | night | noun | DET | []
# night | object of preposition | of | adposition | NOUN | [the, confessed]
# he | nominal subject | confessed | verb | PRON | []
# confessed | relative clause modifier | night | noun | VERB | [he, to, and, dating]
# to | prepositional modifier | confessed | verb | ADP | [me]
# me | object of preposition | to | adposition | PRON | []
# and | coordinating conjunction | confessed | verb | CCONJ | []
# were | auxiliary | dating | verb | AUX | []
# dating | conjunct | confessed | verb | VERB | [were]
# . | punctuation | complimented | verb | PUNCT | []
# Also | adverbial modifier | is | auxiliary | ADV | []
# a | determiner | effect | noun | DET | []
# weird | adjectival modifier | effect | noun | ADJ | [but, cute]
# but | coordinating conjunction | weird | adjective | CCONJ | []
# cute | conjunct | weird | adjective | ADJ | []
# side | compound | effect | noun | NOUN | []
# effect | nominal subject | is | auxiliary | NOUN | [a, weird, side]
# is | root | is | auxiliary | AUX | [Also, effect, were, .]
# that | marker | were | auxiliary | SCONJ | []
# my | possession modifier | cats | noun | PRON | []
# cats | nominal subject | were | auxiliary | NOUN | [my, and, dog]
# and | coordinating conjunction | cats | noun | CCONJ | []
# dog | conjunct | cats | noun | NOUN | []
# were | clausal complement | is | auxiliary | AUX | [that, cats, dovey, too]
# very | adverbial modifier | lovey | adjective | ADV | []
# lovey | adjectival modifier | dovey | noun | ADJ | [very]
# dovey | attribute | were | auxiliary | NOUN | [lovey, on]
# on | prepositional modifier | dovey | noun | ADP | [me]
# me | object of preposition | on | adposition | PRON | []
# too | adverbial modifier | were | auxiliary | ADV | []
# . | punctuation | is | auxiliary | PUNCT | []
# It | nominal subject | worked | verb | PRON | []
# worked | root | worked | verb | VERB | [It, wonders, for, .]
# wonders | direct object | worked | verb | NOUN | []
# for | dative | worked | verb | ADP | [me]
# me | object of preposition | for | adposition | PRON | []
# . | punctuation | worked | verb | PUNCT | []
# Buy | root | Buy | verb | VERB | [IMMEDIATELY]
# this | determiner | IMMEDIATELY | noun | DET | []
# IMMEDIATELY | direct object | Buy | verb | NOUN | [this]

# %% [markdown]
# Let’s see how to pick up the sentiment descriptions first.

# %%
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  for token in doc:
    if token.pos_ == 'ADJ':
      descriptive_term = token
  print(sentence)
  print(f'>{descriptive_term}')
# Out:
# The food we had yesterday was delicious
# >delicious
# My time in Italy was very enjoyable
# >enjoyable
# I found the meal to be tasty
# >tasty
# The internet was slow.
# >slow
# Our experience was suboptimal
# >suboptimal
# anc work in the first 3 days but the proximity sensor on the left bud stopped working
# >left
# shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰
# >good
# Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾
# >
# Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !
# >Legit
# been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog
# >long
# wrong color. poor packaging
# >poor
# Delivery and shipment were both okay.
# >okay
# If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
# Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
# Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
# Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
# Worth the money. Have fun!
# >small
# I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY
# >lovey

# %%
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  for token in doc:
    if token.pos_ == 'ADJ':
      prepend = ''
      for child in token.children:
        if child.pos_ != 'ADV':
          continue
        prepend += child.text + ' '
      descriptive_term = prepend + token.text
  print(sentence)
  print(f'>{descriptive_term}')
# Out:
# The food we had yesterday was delicious
# >delicious
# My time in Italy was very enjoyable
# >very enjoyable
# I found the meal to be tasty
# >tasty
# The internet was slow.
# >slow
# Our experience was suboptimal
# >suboptimal
# anc work in the first 3 days but the proximity sensor on the left bud stopped working
# >left
# shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰
# >good
# Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾
# >
# Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !
# >Legit
# been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog
# >so long
# wrong color. poor packaging
# >poor
# Delivery and shipment were both okay.
# >okay
# If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
# Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
# Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
# Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
# Worth the money. Have fun!
# >small
# I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY
# >very lovey

# %% [markdown]
# As you can see, this time around we picked up very enjoyable as well. Our simplistic algorithm is able to pick up adverbs. It checks for child tokens for each adjective and picks up the adverbs such as “very”, “quite”, etc.

# %%
displacy.render(nlp(sentences[5]), style='dep', options={'compact': True})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="26b7be06aa8a47189994f726c14c3f20-0" class="displacy" width="2600" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">anc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">work</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">days</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">proximity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">sensor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">left</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">bud</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">stopped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26b7be06aa8a47189994f726c14c3f20-0-0" stroke-width="2px" d="M62,452.0 62,427.0 185.0,427.0 185.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26b7be06aa8a47189994f726c14c3f20-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26b7be06aa8a47189994f726c14c3f20-0-1" stroke-width="2px" d="M212,452.0 212,427.0 335.0,427.0 335.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26b7be06aa8a47189994f726c14c3f20-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M335.0,454.0 L339.0,446.0 331.0,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26b7be06aa8a47189994f726c14c3f20-0-2" stroke-width="2px" d="M512,452.0 512,377.0 941.0,377.0 941.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26b7be06aa8a47189994f726c14c3f20-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,454.0 L508,446.0 516,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26b7be06aa8a47189994f726c14c3f20-0-3" stroke-width="2px" d="M662,452.0 662,402.0 938.0,402.0 938.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26b7be06aa8a47189994f726c14c3f20-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,454.0 L658,446.0 666,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26b7be06aa8a47189994f726c14c3f20-0-4" stroke-width="2px" d="M812,452.0 812,427.0 935.0,427.0 935.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26b7be06aa8a47189994f726c14c3f20-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,454.0 L808,446.0 816,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-26b7be06aa8a47189994f726c14c3f20-0-5" stroke-width="2px" d="M362,452.0 362,352.0 944.0,352.0 944.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-26b7be06aa8a47189994f726c14c3f20-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M944.0,454.0 L948.0,446.0 940.0,446.0" fill="currentColor"/

# %% [markdown]
# ### CUSTOM RULES
# [ASPECT SENTIMENT GITHUB LINK](https://github.com/ishikaarora/Aspect-Sentiment-Analysis-on-Amazon-Reviews/blob/master/team01final/code/src/models/aspect_extraction.py)

# %%
# apply_extraction FUNCTION: https://github.com/ishikaarora/Aspect-Sentiment-Analysis-on-Amazon-Reviews/blob/master/team01final/code/src/models/aspect_extraction.py
prod_pronouns = ['it','this','they','these']

def apply_extraction(reviews,nlp):
    review_body = reviews
    # review_id = row['review_id']
    # review_marketplace = row['marketplace']
    # customer_id = row['customer_id']
    # product_parent = row['product_parent']
    # product_title = row['product_title']
    # product_category = row['product_category']
    # date = str(row['review_date'])
    # star_rating = row['star_rating']
    # url = add_amazonlink(product_id)



    doc=nlp(review_body)
    #print("--- SPACY : Doc loaded ---")

    ## FIRST RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    ## RULE = M is child of A with a relationshio of amod
    rule1_pairs = []
    rule2_pairs = []
    rule3_pairs = []
    rule4_pairs = []
    rule5_pairs = []
    rule6_pairs = []
    rule7_pairs = []

    for token in doc:
        A = "999999"
        M = "999999"
        if token.dep_ == "amod" and not token.is_stop:
            M = token.text
            A = token.head.text

            # add adverbial modifier of adjective (e.g. 'most comfortable headphones')
            M_children = token.children
            for child_m in M_children:
                if(child_m.dep_ == "advmod"):
                    M_hash = child_m.text
                    M = M_hash + " " + M
                    break

            # negation in adjective, the "no" keyword is a 'det' of the noun (e.g. no interesting characters)
            A_children = token.head.children
            for child_a in A_children:
                if(child_a.dep_ == "det" and child_a.text == 'no'):
                    neg_prefix = 'not'
                    M = neg_prefix + " " + M
                    break

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict1 = {"noun" : A, "adj" : M, "rule" : 1}
            rule1_pairs.append(dict1)

        # print("--- SPACY : Rule 1 Done ---")

        # # SECOND RULE OF DEPENDANCY PARSE -
        # # M - Sentiment modifier || A - Aspect
        # Direct Object - A is a child of something with relationship of nsubj, while
        # M is a child of the same something with relationship of dobj
        # Assumption - A verb will have only one NSUBJ and DOBJ
        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if((child.dep_ == "dobj" and child.pos_ == "ADJ") and not child.is_stop):
                M = child.text
                #check_spelling(child.text)

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict2 = {"noun" : A, "adj" : M, "rule" : 2}
            rule2_pairs.append(dict2)




        # print("--- SPACY : Rule 2 Done ---")

        ## THIRD RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect
        ## Adjectival Complement - A is a child of something with relationship of nsubj, while
        ## M is a child of the same something with relationship of acomp
        ## Assumption - A verb will have only one NSUBJ and DOBJ
        ## "The sound of the speakers would be better. The sound of the speakers could be better" - handled using AUX dependency

        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if(child.dep_ == "acomp" and not child.is_stop):
                M = child.text

            # example - 'this could have been better' -> (this, not better)
            if(child.dep_ == "aux" and child.tag_ == "MD"):
                neg_prefix = "not"
                add_neg_pfx = True

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M
                #check_spelling(child.text)

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict3 = {"noun" : A, "adj" : M, "rule" : 3}
            rule3_pairs.append(dict3)
            #rule3_pairs.append((A, M, sid.polarity_scores(M)['compound'],3))
    # print("--- SPACY : Rule 3 Done ---")

        ## FOURTH RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect

        #Adverbial modifier to a passive verb - A is a child of something with relationship of nsubjpass, while
        # M is a child of the same something with relationship of advmod

        #Assumption - A verb will have only one NSUBJ and DOBJ

        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if((child.dep_ == "nsubjpass" or child.dep_ == "nsubj") and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if(child.dep_ == "advmod" and not child.is_stop):
                M = child.text
                M_children = child.children
                for child_m in M_children:
                    if(child_m.dep_ == "advmod"):
                        M_hash = child_m.text
                        M = M_hash + " " + child.text
                        break
                #check_spelling(child.text)

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict4 = {"noun" : A, "adj" : M, "rule" : 4}
            rule4_pairs.append(dict4)
            #rule4_pairs.append((A, M,sid.polarity_scores(M)['compound'],4)) # )

    # print("--- SPACY : Rule 4 Done ---")


        ## FIFTH RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect

        #Complement of a copular verb - A is a child of M with relationship of nsubj, while
        # M has a child with relationship of cop

        #Assumption - A verb will have only one NSUBJ and DOBJ

        children = token.children
        A = "999999"
        buf_var = "999999"
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if(child.dep_ == "cop" and not child.is_stop):
                buf_var = child.text
                #check_spelling(child.text)

        if(A != "999999" and buf_var != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict5 = {"noun" : A, "adj" : token.text, "rule" : 5}
            rule5_pairs.append(dict5)
            #rule5_pairs.append((A, token.text,sid.polarity_scores(token.text)['compound'],5))

    # print("--- SPACY : Rule 5 Done ---")

        ## SIXTH RULE OF DEPENDANCY PARSE -
        ## M - Sentiment modifier || A - Aspect
        ## Example - "It ok", "ok" is INTJ (interjections like bravo, great etc)

        children = token.children
        A = "999999"
        M = "999999"
        if(token.pos_ == "INTJ" and not token.is_stop):
            for child in children :
                if(child.dep_ == "nsubj" and not child.is_stop):
                    A = child.text
                    M = token.text
                    # check_spelling(child.text)

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict6 = {"noun" : A, "adj" : M, "rule" : 6}
            rule6_pairs.append(dict6)

            #rule6_pairs.append((A, M,sid.polarity_scores(M)['compound'],6))

    # print("--- SPACY : Rule 6 Done ---")

    ## SEVENTH RULE OF DEPENDANCY PARSE -
    ## M - Sentiment modifier || A - Aspect
    ## ATTR - link between a verb like 'be/seem/appear' and its complement
    ## Example: 'this is garbage' -> (this, garbage)

        children = token.children
        A = "999999"
        M = "999999"
        add_neg_pfx = False
        for child in children :
            if(child.dep_ == "nsubj" and not child.is_stop):
                A = child.text
                # check_spelling(child.text)

            if((child.dep_ == "attr") and not child.is_stop):
                M = child.text
                #check_spelling(child.text)

            if(child.dep_ == "neg"):
                neg_prefix = child.text
                add_neg_pfx = True

        if (add_neg_pfx and M != "999999"):
            M = neg_prefix + " " + M

        if(A != "999999" and M != "999999"):
            if A in prod_pronouns :
                A = "product"
            dict7 = {"noun" : A, "adj" : M, "rule" : 7}
            rule7_pairs.append(dict7)
            #rule7_pairs.append((A, M,sid.polarity_scores(M)['compound'],7))



    #print("--- SPACY : Rules Done ---")


    aspects = []

    aspects = rule1_pairs + rule2_pairs + rule3_pairs +rule4_pairs +rule5_pairs + rule6_pairs + rule7_pairs

    # replace all instances of "it", "this" and "they" with "product"
    #aspects = [(A,M,P,r) if A not in prod_pronouns else ("product",M,P,r) for A,M,P,r in aspects ]

    # dic = {"review_id" : review_id , "aspect_pairs" : aspects, "review_marketplace" : review_marketplace
    # , "customer_id" : customer_id, "product_id" : product_id, "product_parent" : product_parent,
    # "product_title" : product_title, "product_category" : product_category, "date" : date, "star_rating" : star_rating, "url" : url}

    dic = {"aspect_pairs" : aspects}
    # dic = {"review_id" : review_id , "aspect_pairs" : aspects}
    return dic

# %%
for i, sentence in enumerate(sentences):
    print(i, sentence)
# Out:
# 0 The food we had yesterday was delicious
# 1 My time in Italy was very enjoyable
# 2 I found the meal to be tasty
# 3 The internet was slow.
# 4 Our experience was suboptimal
# 5 anc work in the first 3 days but the proximity sensor on the left bud stopped working
# 6 shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰
# 7 Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾
# 8 Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !
# 9 been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog
# 10 wrong color. poor packaging
# 11 Delivery and shipment were both okay.
# 12 If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
# Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
# Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
# Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
# Worth the money. Have fun!
# 13 I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY

# %%
for i, sentence in enumerate(sentences):
    print(i, apply_extraction(sentences[i], nlp))
# Out:
# 0 {'aspect_pairs': [{'noun': 'food', 'adj': 'delicious', 'rule': 3}]}
# 1 {'aspect_pairs': [{'noun': 'time', 'adj': 'enjoyable', 'rule': 3}]}
# 2 {'aspect_pairs': [{'noun': 'meal', 'adj': 'tasty', 'rule': 3}]}
# 3 {'aspect_pairs': [{'noun': 'internet', 'adj': 'slow', 'rule': 3}]}
# 4 {'aspect_pairs': [{'noun': 'experience', 'adj': 'suboptimal', 'rule': 3}]}
# 5 {'aspect_pairs': [{'noun': 'bud', 'adj': 'left', 'rule': 1}]}
# 6 {'aspect_pairs': [{'noun': 'condition', 'adj': 'good', 'rule': 1}, {'noun': 'damage', 'adj': 'not well packed', 'rule': 1}]}
# 7 {'aspect_pairs': []}
# 8 {'aspect_pairs': []}
# 9 {'aspect_pairs': []}
# 10 {'aspect_pairs': [{'noun': 'color', 'adj': 'wrong', 'rule': 1}, {'noun': 'packaging', 'adj': 'poor', 'rule': 1}]}
# 11 {'aspect_pairs': [{'noun': 'Delivery', 'adj': 'okay', 'rule': 3}]}
# 12 {'aspect_pairs': [{'noun': 'result', 'adj': 'ravenous', 'rule': 1}, {'noun': 'result', 'adj': 'passionate', 'rule': 1}, {'noun': 'target', 'adj': 'intended', 'rule': 1}, {'noun': 'move', 'adj': '*', 'rule': 1}, {'noun': 'call', 'adj': 'siren', 'rule': 1}, {'noun': 'smelling', 'adj': 'strong', 'rule': 1}, {'noun': 'trigger', 'adj': 'positive', 'rule': 1}, {'noun': 'target', 'adj': 'intended', 'rule': 1}, {'noun': 'swipe', 'adj': 'small', 'rule': 1}, {'noun': 'stuff', 'adj': 'potent', 'rule': 3}]}
# 13 {'aspect_pairs': [{'noun': 'things', 'adj': 'good', 'rule': 1}, {'noun': 'effect', 'adj': 'weird', 'rule': 1}, {'noun': 'dovey', 'adj': 'very lovey', 'rule': 1}, {'noun': 'cats', 'adj': 'dovey', 'rule': 7}]}

# %% [markdown]
# ---------------------------
# END OF ASPECT GITHUB
# ---------------------------

# %%
aspects = []
for sentence in sentences:
  doc = nlp(sentence)
  descriptive_term = ''
  # target = ''
  target = []
  for token in doc:
    if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
      # target = token.text
      target.append(token.text)
    if token.pos_ == 'ADJ':
      prepend = ''
      for child in token.children:
        if child.pos_ != 'ADV':
          continue
        prepend += child.text + ' '
      descriptive_term = f"<{prepend}>" + token.text
  aspects.append({'aspect': target,
  # aspects.append({'aspect': target,
    'description': descriptive_term})

pprint(aspects)
# Out:
# [{'aspect': ['food'], 'description': '<>delicious'},
#  {'aspect': ['time'], 'description': '<very >enjoyable'},
#  {'aspect': ['meal'], 'description': '<>tasty'},
#  {'aspect': ['internet'], 'description': '<>slow'},
#  {'aspect': ['experience'], 'description': '<>suboptimal'},
#  {'aspect': ['sensor'], 'description': '<>left'},
#  {'aspect': ['damage'], 'description': '<>good'},
#  {'aspect': ['seller'], 'description': ''},
#  {'aspect': [], 'description': '<>Legit'},
#  {'aspect': [], 'description': '<so >long'},
#  {'aspect': [], 'description': '<>poor'},
#  {'aspect': ['Delivery'], 'description': '<>okay'},
#  {'aspect': ['stuff', 'man', 'dab'], 'description': '<>small'},
#  {'aspect': ['effect', 'cats'], 'description': '<very >lovey'}]

# %% [markdown]
# Now our solution is starting to look more complete. We’re able to pick up aspects, even though our application doesn’t “know” anything beforehand. We haven’t hardcoded the aspects such as “food”, “time”, or “meal”. And we also haven’t hardcoded the adjectives such as “tasty”, “slow”, or “enjoyable”.

# %% [markdown]
# # Sentiment Analysis
# Now that we successfully extracted the aspects and descriptions, it’s time to classify them as positive or negative. The goal here is to help the computer understand that tasty food is positive, while slow internet is negative. Computers don’t understand English, so we will need to try a few things before we have a working solution.

# %%
from textblob import TextBlob
for aspect in aspects:
  aspect['sentiment'] = TextBlob(aspect['description']).sentiment
  
pprint(aspects)
# Out:
# [{'aspect': ['food'],
#   'description': '<>delicious',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['time'],
#   'description': '<very >enjoyable',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['meal'],
#   'description': '<>tasty',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['internet'],
#   'description': '<>slow',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['experience'],
#   'description': '<>suboptimal',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['sensor'],
#   'description': '<>left',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['damage'],
#   'description': '<>good',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['seller'],
#   'description': '',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': [],
#   'description': '<>Legit',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': [],
#   'description': '<so >long',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': [],
#   'description': '<>poor',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['Delivery'],
#   'description': '<>okay',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['stuff', 'man', 'dab'],
#   'description': '<>small',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)},
#  {'aspect': ['effect', 'cats'],
#   'description': '<very >lovey',
#   'sentiment': Sentiment(polarity=0.0, subjectivity=0.0)}]

# %%
for i, sentence in enumerate(sentences):
    print(f'{i+1:02}). {sentence}')
# Out:
# 01). The food we had yesterday was delicious
# 02). My time in Italy was very enjoyable
# 03). I found the meal to be tasty
# 04). The internet was slow.
# 05). Our experience was suboptimal
# 06). anc work in the first 3 days but the proximity sensor on the left bud stopped working
# 07). shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰
# 08). Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾
# 09). Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !
# 10). been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog
# 11). wrong color. poor packaging
# 12). Delivery and shipment were both okay.
# 13). If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
# Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
# Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
# Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
# Worth the money. Have fun!
# 14). I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY

# %%
for i, aspect in enumerate(aspects):
    print(f'{i+1:02}.) "{sentences[i]}"')
    print(f'\tASPECT:"{aspect["aspect"]}",',
            f'DESCRIPTION:"{aspect["description"]}",',
            f'POLARITY:{"POSITIVE" if (aspect["sentiment"].polarity) > 0 else "NEGATIVE" if (aspect["sentiment"].polarity) < 0 else "NEUTRAL"}')
    print(f'\t"{aspect["sentiment"]}"\n')
# Out:
# 01.) "The food we had yesterday was delicious"
# 	ASPECT:"['food']", DESCRIPTION:"<>delicious", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 02.) "My time in Italy was very enjoyable"
# 	ASPECT:"['time']", DESCRIPTION:"<very >enjoyable", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 03.) "I found the meal to be tasty"
# 	ASPECT:"['meal']", DESCRIPTION:"<>tasty", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 04.) "The internet was slow."
# 	ASPECT:"['internet']", DESCRIPTION:"<>slow", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 05.) "Our experience was suboptimal"
# 	ASPECT:"['experience']", DESCRIPTION:"<>suboptimal", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 06.) "anc work in the first 3 days but the proximity sensor on the left bud stopped working"
# 	ASPECT:"['sensor']", DESCRIPTION:"<>left", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 07.) "shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰"
# 	ASPECT:"['damage']", DESCRIPTION:"<>good", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 08.) "Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾"
# 	ASPECT:"['seller']", DESCRIPTION:"", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 09.) "Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !"
# 	ASPECT:"[]", DESCRIPTION:"<>Legit", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 10.) "been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog"
# 	ASPECT:"[]", DESCRIPTION:"<so >long", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 11.) "wrong color. poor packaging"
# 	ASPECT:"[]", DESCRIPTION:"<>poor", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 12.) "Delivery and shipment were both okay."
# 	ASPECT:"['Delivery']", DESCRIPTION:"<>okay", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 13.) "If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
# Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
# Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
# Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
# Worth the money. Have fun!"
# 	ASPECT:"['stuff', 'man', 'dab']", DESCRIPTION:"<>small", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"
#
# 14.) "I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY"
# 	ASPECT:"['effect', 'cats']", DESCRIPTION:"<very >lovey", POLARITY:NEUTRAL
# 	"Sentiment(polarity=0.0, subjectivity=0.0)"

# %% [markdown]
# # ASPECT EXTRACTION with CUSTOM SENTIMENT ANALYSIS NAIVE BAYES

# %%
# Importing libraries
import pandas as pd
import re
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import pickle

model = pickle.load(open('modelNB.pkl', 'rb'))

# @app.route('/')
# def home():
#     return render_template('index.html')

def predict(raw_text: str):

    # Instantiate PorterStemmer
    p_stemmer = PorterStemmer()

    # Remove HTML
    review_text = BeautifulSoup(raw_text, features="lxml").get_text()

    # Remove non-letters
    letters_only = re.sub("[^a-zA-Z]", " ", review_text)

    # Convert words to lower case and split each word up
    words = letters_only.lower().split()

    # Convert stopwords to a set
    stops = set(stopwords.words('english'))

    # Adding on stopwords that were appearing frequently in both positive and negative reviews
    stops.update(['app','shopee','shoppee','item','items','seller','sellers','bad'])

    # Remove stopwords
    meaningful_words = [w for w in words if w not in stops]

    # Stem words
    meaningful_words = [p_stemmer.stem(w) for w in meaningful_words]

    # Join words back into one string, with a space in between each word
    final_text = pd.Series(" ".join(meaningful_words))

    # Generate predictions
    pred = model.predict(final_text)[0]

    if pred == 1:
        output = "Negative"
    else:
        output = "Postive"

    return output, pred


text = """
anc work in the first 3 days but the proximity sensor on the left bud stopped working
"""
result = predict(text)
print(f'RAW_TEXT: \t{text}')
print(F'\tSENTIMENT: {result}')
# Out:
# RAW_TEXT:
# anc work in the first 3 days but the proximity sensor on the left bud stopped working
#
# 	SENTIMENT: ('Negative', 1)

# %%
for i, aspect in enumerate(aspects):
    print(f'{i+1:02}.) "{sentences[i]}"')
    print(f'\tASPECT:"{aspect["aspect"]}",',
            f'DESCRIPTION:"{aspect["description"]}",',
            f'SENTIMENT: {predict(aspect["description"])}'
    )
# Out:
# 01.) "The food we had yesterday was delicious"
# 	ASPECT:"['food']", DESCRIPTION:"<>delicious", SENTIMENT: ('Postive', 0)
# 02.) "My time in Italy was very enjoyable"
# 	ASPECT:"['time']", DESCRIPTION:"<very >enjoyable", SENTIMENT: ('Postive', 0)
# 03.) "I found the meal to be tasty"
# 	ASPECT:"['meal']", DESCRIPTION:"<>tasty", SENTIMENT: ('Postive', 0)
# 04.) "The internet was slow."
# 	ASPECT:"['internet']", DESCRIPTION:"<>slow", SENTIMENT: ('Negative', 1)
# 05.) "Our experience was suboptimal"
# 	ASPECT:"['experience']", DESCRIPTION:"<>suboptimal", SENTIMENT: ('Postive', 0)
# 06.) "anc work in the first 3 days but the proximity sensor on the left bud stopped working"
# 	ASPECT:"['sensor']", DESCRIPTION:"<>left", SENTIMENT: ('Postive', 0)
# 07.) "shipped out immediately, received the item in good condition, no damage well packed, thank you shopee and thank you seller, will order again 👍😁👌🫰"
# 	ASPECT:"['damage']", DESCRIPTION:"<>good", SENTIMENT: ('Postive', 0)
# 08.) "Tysm for delivering my items safely. I only expected the seller gave some freebies, but he/she didn't 😂😂😾"
# 	ASPECT:"['seller']", DESCRIPTION:"", SENTIMENT: ('Postive', 0)
# 09.) "Sobrang tagal lang dumating. Pero okay lang, sulit naman. Nakuha ko sya sa halagang 999 pesos. Nagsale kasi. 😍 Thank youuu! Legit !"
# 	ASPECT:"[]", DESCRIPTION:"<>Legit", SENTIMENT: ('Postive', 0)
# 10.) "been using this buds for 2 weeks na and I notice that sometimes it took so long to connect on my laptop and phone I don't know why. then sometimes nagkaproblem sound nya parang basag yung tunog"
# 	ASPECT:"[]", DESCRIPTION:"<so >long", SENTIMENT: ('Negative', 1)
# 11.) "wrong color. poor packaging"
# 	ASPECT:"[]", DESCRIPTION:"<>poor", SENTIMENT: ('Negative', 1)
# 12.) "Delivery and shipment were both okay."
# 	ASPECT:"['Delivery']", DESCRIPTION:"<>okay", SENTIMENT: ('Postive', 0)
# 13.) "If you intend to use this to attract your man, be prepared for a ravenous, passionate result. Do not use if you don’t intend to follow through with your intended target. That’s a d*** move. Plus this stuff is potent and you have no idea how a man might respond to its siren call. It’s basically a love potion so handle with care. But it absolutely works!
# Tip 1: let it settle after application, it’s strong but nice smelling at first, but mellows out over time.
# Tip 2: combine with your perfume of choice, particularly one that has a positive olfactory memory trigger with your partner/intended target.
# Tip 3: don’t use too much, or it becomes a turn OFF (tested and confirmed)! A dab or small swipe on wrists and chest or behind ear/jaw should do it
# Worth the money. Have fun!"
# 	ASPECT:"['stuff', 'man', 'dab']", DESCRIPTION:"<>small", SENTIMENT: ('Postive', 0)
# 14.) "I was hesitant at first but I heard lots of good things about this brand so I got it since I’ve been kinda crushing on a friend of mine and he was coming over for the weekend. I put it on and he complimented the way I smelled twice and by the end of the night he confessed to me and were dating. Also a weird but cute side effect is that my cats and dog were very lovey dovey on me too. It worked wonders for me. Buy this IMMEDIATELY"
# 	ASPECT:"['effect', 'cats']", DESCRIPTION:"<very >lovey", SENTIMENT: ('Postive', 0)
